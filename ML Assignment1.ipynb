# %% [markdown]
# ### The necessary libraries are imported

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## The CSV file. THe header is set to 'None' so that the first row does not act as the header when the file is imported.  and later on the header is added manually

# %%
df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',delimiter=',',header=None)
col=['age', 'Work class','fnlwgt','Education','Education num','Marital-status','Occupation','Relationship','race','Sex','capital-gain','capital-loss','hours-per-week','native-country','class']
df.columns=col

# %%
df.head()
# Out:
#    age         Work class  fnlwgt   Education  Education num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital-status          Occupation    Relationship    race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df['class'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df['Sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %% [markdown]
# ### For loop  to  chane the string value to numeric for attribute"Class"

# %%
new_class = []

for cat in df['class']:
    if cat == ' <=50K':
#         print('xxx')
        cls = new_class.append(0)
    
    else:
#         print('yy')
        cls = new_class.append(1)

df['new_class'] = new_class

df.head()
# Out:
#    age         Work class  fnlwgt   Education  Education num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital-status          Occupation    Relationship    race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class  \
# ...

# %% [markdown]
# ### For loop  to  chane the string value to numeric for attribute"Sex"

# %%
Gender=[]
for cat in df['Sex']:
    if cat ==' Male':
        cls=Gender.append(0)
    
    else:
        cls=Gender.append(1)
        
df['Gender']=Gender
df.head()
# Out:
#    age  Work class  Education  Marital-status  Occupation  Relationship  race  \
# 0   39           0          0               0           0             0     0
# 1   50           1          0               1           1             1     0
# 2   38           2          1               2           2             0     0
# 3   53           2          2               1           2             1     1
# 4   28           2          0               1           3             2     1
#
#    Sex  capital-gain  capital-loss  hours-per-week  native-country  class  \
# 0    0          2174             0              40   United-States      0
# 1    0             0             0              13   United-States      0
# 2    0             0             0              40   United-States      0
# 3    0             0             0              40   United-States      0
# 4    1             0             0              40            Cuba      0
#
# ...

# %% [markdown]
# ### The values  old values are replace with the new ones

# %%
df['Sex']=df['Gender']
df['class']=df['new_class']

# %%
df.head()
# Out:
#    age         Work class  fnlwgt   Education  Education num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital-status          Occupation    Relationship    race  Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White    0
# 1   Married-civ-spouse     Exec-managerial         Husband   White    0
# 2             Divorced   Handlers-cleaners   Not-in-family   White    0
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black    0
# 4   Married-civ-spouse      Prof-specialty            Wife   Black    1
#
#    capital-gain  capital-loss  hours-per-week  native-country  class  \
# 0          2174             0              40   United-States      0
# ...

# %% [markdown]
# ### The attributes taht will not be used for testing and training data are dropped

# %%
df.drop(['fnlwgt','Education num'], axis=1, inplace= True)

# %%
df.head()
# Out:
#    age         Work class   Education       Marital-status  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    race  Sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White    0          2174
# 1     Exec-managerial         Husband   White    0             0
# 2   Handlers-cleaners   Not-in-family   White    0             0
# 3   Handlers-cleaners         Husband   Black    0             0
# 4      Prof-specialty            Wife   Black    1             0
#
#    capital-loss  hours-per-week  native-country  class  new_class  Gender
# 0             0              40   United-States      0          0       0
# ...

# %%
df.drop(['new_class','Gender'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    age         Work class   Education       Marital-status  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    race  Sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White    0          2174
# 1     Exec-managerial         Husband   White    0             0
# 2   Handlers-cleaners   Not-in-family   White    0             0
# 3   Handlers-cleaners         Husband   Black    0             0
# 4      Prof-specialty            Wife   Black    1             0
#
#    capital-loss  hours-per-week  native-country  class
# 0             0              40   United-States      0
# 1             0              13   United-States      0
# ...

# %%
df['Work class'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %% [markdown]
# ### For loop  to  chane the string value to numeric for attribute"WorkClass"

# %%
WorkClass=[]
for cat in df['Work class']:
    if cat ==' State-gov':
        cls=WorkClass.append(0)
    
    elif cat==' Self-emp-not-inc':
            cls=WorkClass.append(1)
    elif cat==' Private':
        cls=WorkClass.append(2)
    elif cat==' Federal-gov':
        cls=WorkClass.append(3)
        
    elif cat==' Local-gov':
        cls=WorkClass.append(4)
    elif cat==' ?':
        cls=WorkClass.append(5)
    elif cat==' Self-emp-inc':
        cls=WorkClass.append(6)
    elif cat==' Without-pay':
        cls=WorkClass.append(7)
        
    elif cat==' Never-worked':
        cls=WorkClass.append(8)
        
df['WorkClass']=WorkClass
df.head()
# Out:
#    age         Work class   Education       Marital-status  \
# 0   39          State-gov   Bachelors        Never-married
# 1   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 2   38            Private     HS-grad             Divorced
# 3   53            Private        11th   Married-civ-spouse
# 4   28            Private   Bachelors   Married-civ-spouse
#
#            Occupation    Relationship    race  Sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White    0          2174
# 1     Exec-managerial         Husband   White    0             0
# 2   Handlers-cleaners   Not-in-family   White    0             0
# 3   Handlers-cleaners         Husband   Black    0             0
# 4      Prof-specialty            Wife   Black    1             0
#
#    capital-loss  hours-per-week  native-country  class  WorkClass
# 0             0              40   United-States      0          0
# 1             0              13   United-States      0          1
# ...

# %% [markdown]
# ### Values replaced

# %%
df['Work class']=df['WorkClass']
df.head()
# Out:
#    age  Work class   Education       Marital-status          Occupation  \
# 0   39           0   Bachelors        Never-married        Adm-clerical
# 1   50           1   Bachelors   Married-civ-spouse     Exec-managerial
# 2   38           2     HS-grad             Divorced   Handlers-cleaners
# 3   53           2        11th   Married-civ-spouse   Handlers-cleaners
# 4   28           2   Bachelors   Married-civ-spouse      Prof-specialty
#
#      Relationship    race  Sex  capital-gain  capital-loss  hours-per-week  \
# 0   Not-in-family   White    0          2174             0              40
# 1         Husband   White    0             0             0              13
# 2   Not-in-family   White    0             0             0              40
# 3         Husband   Black    0             0             0              40
# 4            Wife   Black    1             0             0              40
#
#    native-country  class  WorkClass
# 0   United-States      0          0
# ...

# %%
df['Marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
#For loop  to  chane the string value to numeric for attribute"CMarital-status"
MaritalStatus=[]
for cat in df['Marital-status']:
    if cat ==' Never-married':
        cls=MaritalStatus.append(0)
    
    elif cat==' Married-civ-spouse':
            cls=MaritalStatus.append(1)
    elif cat==' Divorced':
        cls=MaritalStatus.append(2)
    elif cat==' Married-spouse-absent':
        cls=MaritalStatus.append(3)
        
    elif cat==' Separated':
        cls=MaritalStatus.append(4)
    elif cat==' Married-AF-spouse':
        cls=MaritalStatus.append(5)
    elif cat==' Widowed':
        cls=MaritalStatus.append(6)
        
df['MaritalStatus']=MaritalStatus
df.head()
# Out:
#    age  Work class   Education       Marital-status          Occupation  \
# 0   39           0   Bachelors        Never-married        Adm-clerical
# 1   50           1   Bachelors   Married-civ-spouse     Exec-managerial
# 2   38           2     HS-grad             Divorced   Handlers-cleaners
# 3   53           2        11th   Married-civ-spouse   Handlers-cleaners
# 4   28           2   Bachelors   Married-civ-spouse      Prof-specialty
#
#      Relationship    race  Sex  capital-gain  capital-loss  hours-per-week  \
# 0   Not-in-family   White    0          2174             0              40
# 1         Husband   White    0             0             0              13
# 2   Not-in-family   White    0             0             0              40
# 3         Husband   Black    0             0             0              40
# 4            Wife   Black    1             0             0              40
#
#    native-country  class  WorkClass  MaritalStatus
# ...

# %%
#values replaced
df['Marital-status']=df['MaritalStatus']
df.head()
# Out:
#    age  Work class   Education  Marital-status          Occupation  \
# 0   39           0   Bachelors               0        Adm-clerical
# 1   50           1   Bachelors               1     Exec-managerial
# 2   38           2     HS-grad               2   Handlers-cleaners
# 3   53           2        11th               1   Handlers-cleaners
# 4   28           2   Bachelors               1      Prof-specialty
#
#      Relationship    race  Sex  capital-gain  capital-loss  hours-per-week  \
# 0   Not-in-family   White    0          2174             0              40
# 1         Husband   White    0             0             0              13
# 2   Not-in-family   White    0             0             0              40
# 3         Husband   Black    0             0             0              40
# 4            Wife   Black    1             0             0              40
#
#    native-country  class  WorkClass  MaritalStatus
# 0   United-States      0          0              0
# ...

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %% [markdown]
# ### For loop  to  chane the string value to numeric for attribute"race"

# %%
Race=[]
for cat in df['race']:
    if cat ==' White':
        cls=Race.append(0)
    
    elif cat==' Black':
        cls=Race.append(1)
    elif cat==' Asian-Pac-Islander':
        cls=Race.append(2)
    elif cat==' Amer-Indian-Eskimo':
        cls=Race.append(3)
        
    elif cat==' Other':
        cls=Race.append(4)
    
        
df['Race']=Race
df.head()
# Out:
#    age  Work class   Education  Marital-status          Occupation  \
# 0   39           0   Bachelors               0        Adm-clerical
# 1   50           1   Bachelors               1     Exec-managerial
# 2   38           2     HS-grad               2   Handlers-cleaners
# 3   53           2        11th               1   Handlers-cleaners
# 4   28           2   Bachelors               1      Prof-specialty
#
#      Relationship    race  Sex  capital-gain  capital-loss  hours-per-week  \
# 0   Not-in-family   White    0          2174             0              40
# 1         Husband   White    0             0             0              13
# 2   Not-in-family   White    0             0             0              40
# 3         Husband   Black    0             0             0              40
# 4            Wife   Black    1             0             0              40
#
#    native-country  class  WorkClass  MaritalStatus  Race
# ...

# %% [markdown]
# ### values replaced

# %%
df['race']=df['Race']
df.head()
# Out:
#    age  Work class   Education  Marital-status          Occupation  \
# 0   39           0   Bachelors               0        Adm-clerical
# 1   50           1   Bachelors               1     Exec-managerial
# 2   38           2     HS-grad               2   Handlers-cleaners
# 3   53           2        11th               1   Handlers-cleaners
# 4   28           2   Bachelors               1      Prof-specialty
#
#      Relationship  race  Sex  capital-gain  capital-loss  hours-per-week  \
# 0   Not-in-family     0    0          2174             0              40
# 1         Husband     0    0             0             0              13
# 2   Not-in-family     0    0             0             0              40
# 3         Husband     1    0             0             0              40
# 4            Wife     1    1             0             0              40
#
#    native-country  class  WorkClass  MaritalStatus  Race
# 0   United-States      0          0              0     0
# ...

# %%
df['Occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %% [markdown]
# ### For loop to chane the string value to numeric for attribute "Occupation"

# %%
#For loop  to  chane the string value to numeric for attribute"Occupation"
occ=[]
for cat in df['Occupation']:
    if cat ==' Adm-clerical':
        cls=occ.append(0)
    
    elif cat==' Exec-managerial':
            cls=occ.append(1)
        
    elif cat==' Handlers-cleaners':
        cls=occ.append(2)
        
    elif cat==' Prof-specialty':
        cls=occ.append(3)
        
    elif cat==' Other-service':
        cls=occ.append(4)
        
    elif cat==' Sales':
        cls=occ.append(5)
        
    elif cat==' Craft-repair':
        cls=occ.append(6)
        
    elif cat==' Transport-moving':
        cls=occ.append(7)
        
    elif cat==' Farming-fishing':
        cls=occ.append(8)
        
    elif cat==' Machine-op-inspct':
        cls=occ.append(9)
        
    elif cat==' ?':
        cls=occ.append(10)
        
    elif cat==' Protective-serv':
        cls=occ.append(11)
        
    elif cat==' Armed-Forces':
        cls=occ.append(12)
        
    elif cat==' Priv-house-serv':
        cls=occ.append(13)
        
    elif cat==' Tech-support':
        cls=occ.append(14)
        
    
        
df['occ']=occ
df.head()
# Out:
#    age  Work class   Education  Marital-status          Occupation  \
# 0   39           0   Bachelors               0        Adm-clerical
# 1   50           1   Bachelors               1     Exec-managerial
# 2   38           2     HS-grad               2   Handlers-cleaners
# 3   53           2        11th               1   Handlers-cleaners
# 4   28           2   Bachelors               1      Prof-specialty
#
#      Relationship  race  Sex  capital-gain  capital-loss  hours-per-week  \
# 0   Not-in-family     0    0          2174             0              40
# 1         Husband     0    0             0             0              13
# 2   Not-in-family     0    0             0             0              40
# 3         Husband     1    0             0             0              40
# 4            Wife     1    1             0             0              40
#
#    native-country  class  WorkClass  MaritalStatus  Race  occ
# ...

# %%
df['Occupation']=df['occ']
df.head()
# Out:
#    age  Work class   Education  Marital-status  Occupation    Relationship  \
# 0   39           0   Bachelors               0           0   Not-in-family
# 1   50           1   Bachelors               1           1         Husband
# 2   38           2     HS-grad               2           2   Not-in-family
# 3   53           2        11th               1           2         Husband
# 4   28           2   Bachelors               1           3            Wife
#
#    race  Sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0     0    0          2174             0              40   United-States
# 1     0    0             0             0              13   United-States
# 2     0    0             0             0              40   United-States
# 3     1    0             0             0              40   United-States
# 4     1    1             0             0              40            Cuba
#
#    class  WorkClass  MaritalStatus  Race  occ
# ...

# %%
df['Education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %% [markdown]
# ### For loop to chane the string value to numeric for attribute "Education"

# %%
#For loop  to  chane the string value to numeric for attribute"Education"
edu=[]
for cat in df['Education']:
    if cat ==' Bachelors':
        cls=edu.append(0)
    
    elif cat==' HS-grad':
            cls=edu.append(1)
        
    elif cat==' 11th':
        cls=edu.append(2)
        
    elif cat==' 9th':
        cls=edu.append(3)
        
    elif cat==' Some-college':
        cls=edu.append(4)
        
    elif cat== ' Assoc-acdm':
        cls=edu.append(5)
        
    elif cat==' Assoc-voc':
        cls=edu.append(6)
        
    elif cat==' 7th-8th':
        cls=edu.append(7)
        
    elif cat==' Doctorate':
        cls=edu.append(8)
        
    elif cat==' Prof-school':
        cls=edu.append(9)
        
    elif cat==' 5th-6th':
        cls=edu.append(10)
        
    elif cat==' 10th':
        cls=edu.append(11)
        
    elif cat==' 1st-4th':
        cls=edu.append(12)
        
    elif cat==' Preschool':
        cls=edu.append(13)
        
    elif cat==' 12th':
        cls=edu.append(14)

    elif cat== ' Masters':
        cls=edu.append(15)
    
        
df['edu']=edu
df.head()
# Out:
#    age  Work class   Education  Marital-status  Occupation    Relationship  \
# 0   39           0   Bachelors               0           0   Not-in-family
# 1   50           1   Bachelors               1           1         Husband
# 2   38           2     HS-grad               2           2   Not-in-family
# 3   53           2        11th               1           2         Husband
# 4   28           2   Bachelors               1           3            Wife
#
#    race  Sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0     0    0          2174             0              40   United-States
# 1     0    0             0             0              13   United-States
# 2     0    0             0             0              40   United-States
# 3     1    0             0             0              40   United-States
# 4     1    1             0             0              40            Cuba
#
#    class  WorkClass  MaritalStatus  Race  occ  edu
# ...

# %%
df['Education']=df['edu']
df.head()
# Out:
#    age  Work class  Education  Marital-status  Occupation    Relationship  \
# 0   39           0          0               0           0   Not-in-family
# 1   50           1          0               1           1         Husband
# 2   38           2          1               2           2   Not-in-family
# 3   53           2          2               1           2         Husband
# 4   28           2          0               1           3            Wife
#
#    race  Sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0     0    0          2174             0              40   United-States
# 1     0    0             0             0              13   United-States
# 2     0    0             0             0              40   United-States
# 3     1    0             0             0              40   United-States
# 4     1    1             0             0              40            Cuba
#
#    class  WorkClass  MaritalStatus  Race  occ  edu
# ...

# %%
df['Relationship'].unique()
# Out:
# array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %% [markdown]
# ### For loop to chane the string value to numeric for attribute "Relationship"

# %%
#For loop  to  chane the string value to numeric for attribute"Relationship"
rel=[]
for cat in df['Relationship']:
    if cat ==' Not-in-family':
        cls=rel.append(0)
    
    elif cat==' Husband':
        cls=rel.append(1)
        
    elif cat==' Wife':
        cls=rel.append(2)
        
    elif cat==' Own-child':
        cls=rel.append(3)
        
    elif cat==' Unmarried':
        cls=rel.append(4)
        
    elif cat==' Other-relative':
        cls=rel.append(5)
        
df['rel']=rel
df.head()
# Out:
#    age  Work class  Education  Marital-status  Occupation    Relationship  \
# 0   39           0          0               0           0   Not-in-family
# 1   50           1          0               1           1         Husband
# 2   38           2          1               2           2   Not-in-family
# 3   53           2          2               1           2         Husband
# 4   28           2          0               1           3            Wife
#
#    race  Sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0     0    0          2174             0              40   United-States
# 1     0    0             0             0              13   United-States
# 2     0    0             0             0              40   United-States
# 3     1    0             0             0              40   United-States
# 4     1    1             0             0              40            Cuba
#
#    class  WorkClass  MaritalStatus  Race  occ  edu  rel
# ...

# %%
df['Relationship']=df['rel']
df.head()
# Out:
#    age  Work class  Education  Marital-status  Occupation  Relationship  race  \
# 0   39           0          0               0           0             0     0
# 1   50           1          0               1           1             1     0
# 2   38           2          1               2           2             0     0
# 3   53           2          2               1           2             1     1
# 4   28           2          0               1           3             2     1
#
#    Sex  capital-gain  capital-loss  hours-per-week  native-country  class  \
# 0    0          2174             0              40   United-States      0
# 1    0             0             0              13   United-States      0
# 2    0             0             0              40   United-States      0
# 3    0             0             0              40   United-States      0
# 4    1             0             0              40            Cuba      0
#
#    WorkClass  MaritalStatus  Race  occ  edu  rel
# ...

# %%
#The duplicate ttributes are dropped
df1=df.drop(['edu','rel','occ','Race','MaritalStatus','WorkClass'],axis=1)
df1.head()
# Out:
#    age  Work class  Education  Marital-status  Occupation  Relationship  race  \
# 0   39           0          0               0           0             0     0
# 1   50           1          0               1           1             1     0
# 2   38           2          1               2           2             0     0
# 3   53           2          2               1           2             1     1
# 4   28           2          0               1           3             2     1
#
#    Sex  capital-gain  capital-loss  hours-per-week  native-country  class
# 0    0          2174             0              40   United-States      0
# 1    0             0             0              13   United-States      0
# 2    0             0             0              40   United-States      0
# 3    0             0             0              40   United-States      0
# 4    1             0             0              40            Cuba      0

# %% [markdown]
# ### The input and the output values are set for testing and training data. 70-30 split.
# ### First classification model in KNN

# %%
#the inout and the target values are defined.
df1_input = df1.iloc[:,0:10] #[r,c]
df1_target = df1.iloc[:,12]
x=df1_input
y=df1_target

#Import the necessary packages from sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.30, stratify=y)
knn=KNeighborsClassifier(n_neighbors=7)

#Measuring model performance
knn.fit(x_train,y_train)

print(knn.score(x_test,y_test))#Print the Accuracy

#Print prediction
y_pred = knn.predict(x_test)
print("Test set predictions:\n {}".format(y_pred))
# Out:
# 0.8404135530760569
# Test set predictions:
#  [0 1 0 ... 0 0 0]

# %% [markdown]
# ## Confusion Matrix

# %%
#Import the necessary libraries to calculate and print the confusion matrix
from sklearn.metrics import confusion_matrix
matrix=confusion_matrix(y_test,y_pred)
print(matrix)
# Out:
# [[6723  694]
#  [ 904 1448]]

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.88      0.91      0.89      7417
#           1       0.68      0.62      0.64      2352
#
# avg / total       0.83      0.84      0.83      9769

# %% [markdown]
# # Second Clasification model

# %%
from sklearn.linear_model import LogisticRegression
# Create training and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state=42)

# Create the classifier: logreg
logreg = LogisticRegression()

# Fit the classifier to the training data
logreg.fit(x_train, y_train)

# Predict the labels of the test set: y_pred
y_pred = logreg.predict(x_test)
print(logreg.score(x_test,y_test))
print(y_pred)
# Out:
# 0.806223769065411
# [0 0 0 ... 0 0 1]

# %%
# Compute and print the confusion matrix and classification report
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[7180  275]
#  [1618  696]]
#              precision    recall  f1-score   support
#
#           0       0.82      0.96      0.88      7455
#           1       0.72      0.30      0.42      2314
#
# avg / total       0.79      0.81      0.77      9769

# %%
# Import necessary modules
from sklearn.metrics import roc_curve

# Compute predicted probabilities: y_pred_prob
y_pred_prob = logreg.predict_proba(x_test)[:,1]

# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# # Third classification model

# %%
from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification
x, y = make_classification(n_features=10, random_state=0)
clf = LinearSVC(random_state=0, tol=1e-5)
clf.fit(x, y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=1e-05, verbose=0)

# %% [markdown]
# ### Prediction output.

# %%
print(clf.coef_)
print(clf.intercept_)
print(clf.predict([[0, 0, 0, 0,1,0,1,0,1,0]]))
# Out:
# [[-0.00543957 -0.07687791  0.09499741  0.08547534 -0.00581678 -0.06336211
#    0.40273872  0.50818664  0.13397709  0.38091287]]
# [0.39386102]
# [1]

# %% [markdown]
# ### Confusion matrix and classification report

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[7180  275]
#  [1618  696]]
#              precision    recall  f1-score   support
#
#           0       0.82      0.96      0.88      7455
#           1       0.72      0.30      0.42      2314
#
# avg / total       0.79      0.81      0.77      9769
